# %%
# Tudat imports for propagation and estimation
from tudatpy.interface import spice
from tudatpy import dynamics
from tudatpy.dynamics import environment_setup
from tudatpy.dynamics import propagation_setup, parameters_setup, simulator
from tudatpy import estimation
from tudatpy.estimation import observable_models_setup, observable_models, observations_setup, observations, estimation_analysis
from tudatpy.astro.time_representation import DateTime

# import MPC interface
from tudatpy.data.mpc import BatchMPC

# import SBDB interface
from tudatpy.data.sbdb import SBDBquery

# other useful modules
import numpy as np
import datetime

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.cm as cm

# Horizons
from tudatpy.data.horizons import HorizonsQuery

# %%
# SPICE KERNELS
spice.load_standard_kernels()

# %%
target_mpc_code = 66146

observations_start = datetime.datetime(2000,1,1)
observations_end = datetime.datetime(2014, 1, 1)

# number of iterations for our estimation
number_of_pod_iterations = 6

# timestep of 20 hours for our estimation
timestep_global = 20 * 3600.0

# 1 month time buffer used to avoid interpolation errors:
time_buffer = 1 * 31 * 86400.0

# define the frame origin and orientation.
global_frame_origin = "SSB"
global_frame_orientation = "J2000"

# %%
target_sbdb = SBDBquery(target_mpc_code)

mpc_codes = [target_mpc_code]  # the BatchMPC interface requires a list.
target_spkid = target_sbdb.codes_300_spkid  # the ID used by the
target_name = target_sbdb.name  # the ID used by the

print(f"SPK ID for {target_name} is: {target_spkid}")
# Out:
# SPK ID for 66146 (1998 TU3) is: 2066146

# %%
batch = BatchMPC()
batch.get_observations(mpc_codes)
batch.filter(
    epoch_start=observations_start,
    epoch_end=observations_end,
)

batch.summary()
# Out:
#    Batch Summary:
# 1. Batch includes 1 minor planets:
#    ['66146']
# 2. Batch includes 588 observations, including 20 observations from space telescopes
# 3. The observations range from 2000-09-03 08:49:24.959992 to 2012-11-25 05:23:06.432002
#    In seconds TDB since J2000: 21243029.142585397 to 407093053.6149815
#    In Julian Days: 2451790.86765 to 2456256.72438
# 4. The batch contains observations from 44 observatories, including 1 space telescopes
# /opt/anaconda3/envs/tudat-space/lib/python3.10/site-packages/tudatpy/data/mpc/mpc.py:866: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['66146' '66146' '66146' ... '66146' '66146' '66146']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   obs.loc[:, "number"] = obs.number.astype(str)

# %%
print("Summary of space telescopes in batch:")
print(batch.observatories_table(only_space_telescopes=True))
# Out:
# Summary of space telescopes in batch:
#      Code  Name  count
# 1239  C51  WISE   20.0

# %%
obs_by_WISE = (
    batch.table.query("observatory == 'C51'")
    .loc[:, ["number", "epochJ2000secondsTDB", "RA", "DEC"]]
    .iloc[[0, -1]]
)

print("\nInitial and Final Observations by WISE:")
print(obs_by_WISE)
# Out:
# Initial and Final Observations by WISE:
#     number  epochJ2000secondsTDB        RA       DEC
# 615  66146          3.351648e+08  0.940892  0.109951
# 742  66146          3.427499e+08  5.865048 -0.611552

# %%
# List the bodies for our environment
bodies_to_create = [
    "Sun",
    "Mercury",
    "Venus",
    "Earth",
    "Moon",
    "Mars",
    "Jupiter",
    "Saturn",
    "Uranus",
    "Neptune",
]

# Create system of bodies
body_settings = environment_setup.get_default_body_settings(
    bodies_to_create, global_frame_origin, global_frame_orientation
)

bodies = environment_setup.create_system_of_bodies(body_settings)

# Retrieve Eros' body name from BatchMPC and set its centre to enable its propagation
bodies_to_propagate = batch.MPC_objects
central_bodies = [global_frame_origin]

# %%
print(bodies_to_propagate)
# Out:
# ['66146']

# %%
# Transform the MPC observations into a tudat compatible format.
# note that we explicitly exclude all satellite observations in this step by setting included satellites to None.
observation_collection = batch.to_tudat(bodies=bodies, included_satellites=None)

# set create angular_position settings for each link in the list.
observation_settings_list = list()
link_list = list(
    observation_collection.get_link_definitions_for_observables(
        observable_type=observable_models_setup.model_settings.angular_position_type
    )
)

for link in link_list:
    # add optional bias settings here
    observation_settings_list.append(
        observable_models_setup.model_settings.angular_position(link, bias_settings=None)
    )
# Retrieve the first and final observation epochs and add the buffer
epoch_start_nobuffer = batch.epoch_start
epoch_end_nobuffer = batch.epoch_end

epoch_start_buffer = epoch_start_nobuffer - time_buffer
epoch_end_buffer = epoch_end_nobuffer + time_buffer
# Out:
# /opt/anaconda3/envs/tudat-space/lib/python3.10/site-packages/tudatpy/data/mpc/mpc.py:147: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   bias_dataframe = bias_dataframe.stack(level=0)

# %%
# Define accelerations
accelerations = {
    "Sun": [
        propagation_setup.acceleration.point_mass_gravity(),
        propagation_setup.acceleration.relativistic_correction(use_schwarzschild=True),
    ],
    "Mercury": [propagation_setup.acceleration.point_mass_gravity()],
    "Venus": [propagation_setup.acceleration.point_mass_gravity()],
    "Earth": [propagation_setup.acceleration.point_mass_gravity()],
    "Moon": [propagation_setup.acceleration.point_mass_gravity()],
    "Mars": [propagation_setup.acceleration.point_mass_gravity()],
    "Jupiter": [propagation_setup.acceleration.point_mass_gravity()],
    "Saturn": [propagation_setup.acceleration.point_mass_gravity()],
    "Uranus": [propagation_setup.acceleration.point_mass_gravity()],
    "Neptune": [propagation_setup.acceleration.point_mass_gravity()],
}

# Set up the accelerations settings for each body, in this case only Eros
acceleration_settings = {}
for body in batch.MPC_objects:
    acceleration_settings[str(body)] = accelerations

# create the acceleration models.
acceleration_models = propagation_setup.create_acceleration_models(
    bodies, acceleration_settings, bodies_to_propagate, central_bodies
)

# %%
# benchmark state for later comparison retrieved from SPICE
initial_states = HorizonsQuery(
    query_id="66146;",
    location="@0",  # SSB
    epoch_start = epoch_start_buffer,
    epoch_end = epoch_end_buffer,
    epoch_step = "20h",
    extended_query=True,
)

# Add random offset for initial guess
rng = np.random.default_rng(seed=1)

initial_position_offset = 1e6 * 1000
initial_velocity_offset = 100

jpl_vector = initial_states.cartesian()
initial_jpl_vector = jpl_vector[0][1:7]
initial_guess = initial_jpl_vector.copy()
initial_guess[0:3] += (2 * rng.random(3) - 1) * initial_position_offset
initial_guess[3:6] += (2 * rng.random(3) - 1) * initial_velocity_offset

print("Error between the real initial state and our initial guess:")
print(initial_guess - initial_jpl_vector)
# Out:
# Error between the real initial state and our initial guess:
# [ 2.36432494e+07  9.00927393e+08 -7.11680775e+08  8.97298894e+01
#  -3.76337096e+01 -1.53347102e+01]

# %%
# Create numerical integrator settings
integrator_settings = propagation_setup.integrator.runge_kutta_variable_step_size(
    timestep_global,
    propagation_setup.integrator.CoefficientSets.rkf_78,
    timestep_global,
    timestep_global,
    1.0,
    1.0,
)
# Terminate at the time of oldest observation
termination_condition = propagation_setup.propagator.time_termination(epoch_end_buffer)


# Create propagation settings
propagator_settings = propagation_setup.propagator.translational(
    central_bodies=central_bodies,
    acceleration_models=acceleration_models,
    bodies_to_integrate=bodies_to_propagate,
    initial_states=initial_guess,
    initial_time=epoch_start_buffer,
    integrator_settings=integrator_settings,
    termination_settings=termination_condition,
)

# %%
# Setup parameters settings to propagate the state transition matrix
parameter_settings = parameters_setup.initial_states(
    propagator_settings, bodies
)

# Create the parameters that will be estimated
parameters_to_estimate = parameters_setup.create_parameter_set(
    parameter_settings, bodies, propagator_settings
)

# %%
parameters_to_estimate.get_parameter_descriptions()
# Out:
# ['translational state of (66146).']

# %%
# Set up the estimator
estimator = estimation_analysis.Estimator(
    bodies=bodies,
    estimated_parameters=parameters_to_estimate,
    observation_settings=observation_settings_list,
    propagator_settings=propagator_settings,
    integrate_on_creation=True,
)

# provide the observation collection as input, and limit number of iterations for estimation.
pod_input = estimation_analysis.EstimationInput(
    observations_and_times=observation_collection,
    convergence_checker=estimation.estimation_analysis.estimation_convergence_checker(
        maximum_iterations=number_of_pod_iterations,
    ),
)

# Set methodological options
pod_input.define_estimation_settings(reintegrate_variational_equations=True)

# %%
# Perform the estimation
pod_output = estimator.perform_estimation(pod_input)
# Out:
# Calculating residuals and partials 1136
# Current residual: 1.48601
# Parameter update-5.97519e+09 -1.38966e+11  1.62345e+09        79303       -11578     -23617.8
# Calculating residuals and partials 1136
# Current residual: 1.89376
# Parameter update 3.80888e+12  2.71486e+12 -2.99687e+11      -802558       540940       285245
# Calculating residuals and partials 1136
# Current residual: 1.47687
# Parameter update-3.27697e+15 -2.34394e+15  2.70582e+14   6.6028e+08  -4.3065e+08 -2.39888e+08
# Calculating residuals and partials 1136
# Warning, detected jump in observation residual of size 5.91545 for observable type 1
# Warning, detected jump in observation residual of size 5.90335 for observable type 1
# Warning, detected jump in observation residual of size 5.90333 for observable type 1
# Warning, detected jump in observation residual of size 5.90333 for observable type 1
# Warning, detected jump in observation residual of size 4.54795 for observable type 1
# Warning, detected jump in observation residual of size 4.60871 for observable type 1
# Warning, detected jump in observation residual of size 4.60864 for observable type 1
# Warning, detected jump in observation residual of size 4.60864 for observable type 1
# Warning, detected jump in observation residual of size 4.60857 for observable type 1
# Warning, detected jump in observation residual of size 4.60857 for observable type 1
# Warning, detected jump in observation residual of size 4.41215 for observable type 1
# Warning, detected jump in observation residual of size 4.39113 for observable type 1
# Warning, detected jump in observation residual of size 4.39104 for observable type 1
# Warning, detected jump in observation residual of size 4.39103 for observable type 1
# Warning, detected jump in observation residual of size 4.39093 for observable type 1
# Warning, detected jump in observation residual of size 4.39092 for observable type 1
# Warning, detected jump in observation residual of size 4.24398 for observable type 1
# Warning, detected jump in observation residual of size 4.21094 for observable type 1
# Warning, detected jump in observation residual of size 4.21086 for observable type 1
# Warning, detected jump in observation residual of size 4.21083 for observable type 1
# Warning, detected jump in observation residual of size 4.21074 for observable type 1
# Warning, detected jump in observation residual of size 4.21072 for observable type 1
# Warning, detected jump in observation residual of size 3.93676 for observable type 1
# Warning, detected jump in observation residual of size 3.8251 for observable type 1
# Warning, detected jump in observation residual of size 3.82499 for observable type 1
# Warning, detected jump in observation residual of size 3.82492 for observable type 1
# Warning, detected jump in observation residual of size 3.82483 for observable type 1
# Warning, detected jump in observation residual of size 3.82477 for observable type 1
# Warning, detected jump in observation residual of size 3.46546 for observable type 1
# Warning, detected jump in observation residual of size 3.18342 for observable type 1
# Warning, detected jump in observation residual of size 3.18328 for observable type 1
# Warning, detected jump in observation residual of size 3.18313 for observable type 1
# Warning, detected jump in observation residual of size 3.18298 for observable type 1
# Warning, detected jump in observation residual of size 3.18283 for observable type 1
# Warning, detected jump in observation residual of size 3.12912 for observable type 1
# Warning, detected jump in observation residual of size 3.07259 for observable type 1
# Warning, detected jump in observation residual of size 3.07254 for observable type 1
# Warning, detected jump in observation residual of size 3.07248 for observable type 1
# Warning, detected jump in observation residual of size 3.07242 for observable type 1
# Warning, detected jump in observation residual of size 3.07236 for observable type 1
# Warning, detected jump in observation residual of size 3.36776 for observable type 1
# Warning, detected jump in observation residual of size 4.41761 for observable type 1
# Warning, detected jump in observation residual of size 4.41755 for observable type 1
# Warning, detected jump in observation residual of size 4.41754 for observable type 1
# Warning, detected jump in observation residual of size 4.41747 for observable type 1
# Warning, detected jump in observation residual of size 4.41746 for observable type 1
# Warning, detected jump in observation residual of size 4.4174 for observable type 1
# Warning, detected jump in observation residual of size 4.4174 for observable type 1
# Warning, detected jump in observation residual of size 4.41733 for observable type 1
# Warning, detected jump in observation residual of size 4.41732 for observable type 1
# Warning, detected jump in observation residual of size 4.06751 for observable type 1
# Warning, detected jump in observation residual of size 3.96578 for observable type 1
# Warning, detected jump in observation residual of size 3.96571 for observable type 1
# Warning, detected jump in observation residual of size 3.96568 for observable type 1
# Warning, detected jump in observation residual of size 3.96561 for observable type 1
# Warning, detected jump in observation residual of size 3.96558 for observable type 1
# Warning, detected jump in observation residual of size 3.96552 for observable type 1
# Warning, detected jump in observation residual of size 3.9655 for observable type 1
# Warning, detected jump in observation residual of size 3.96543 for observable type 1
# Warning, detected jump in observation residual of size 3.9654 for observable type 1
# Warning, detected jump in observation residual of size 3.96534 for observable type 1
# Warning, detected jump in observation residual of size 3.96531 for observable type 1
# Warning, detected jump in observation residual of size 5.98002 for observable type 1
# Warning, detected jump in observation residual of size 5.76523 for observable type 1
# Warning, detected jump in observation residual of size 5.7652 for observable type 1
# Warning, detected jump in observation residual of size 5.76519 for observable type 1
# Warning, detected jump in observation residual of size 5.76516 for observable type 1
# Warning, detected jump in observation residual of size 5.76516 for observable type 1
# Warning, detected jump in observation residual of size 5.90854 for observable type 1
# Warning, detected jump in observation residual of size 5.95584 for observable type 1
# Warning, detected jump in observation residual of size 5.89966 for observable type 1
# Warning, detected jump in observation residual of size 5.89963 for observable type 1
# Warning, detected jump in observation residual of size 5.89954 for observable type 1
# Warning, detected jump in observation residual of size 5.89952 for observable type 1
# Warning, detected jump in observation residual of size 5.89943 for observable type 1
# Warning, detected jump in observation residual of size 5.8994 for observable type 1
# Warning, detected jump in observation residual of size 3.13821 for observable type 1
# Warning, detected jump in observation residual of size 3.13754 for observable type 1
# Warning, detected jump in observation residual of size 3.13687 for observable type 1
# Warning, detected jump in observation residual of size 3.1362 for observable type 1
# Warning, detected jump in observation residual of size 3.13552 for observable type 1
# Warning, detected jump in observation residual of size 5.98233 for observable type 1
# Warning, detected jump in observation residual of size 5.85039 for observable type 1
# Warning, detected jump in observation residual of size 5.73111 for observable type 1
# Warning, detected jump in observation residual of size 5.73082 for observable type 1
# Warning, detected jump in observation residual of size 5.73077 for observable type 1
# Warning, detected jump in observation residual of size 5.88524 for observable type 1
# Warning, detected jump in observation residual of size 5.57735 for observable type 1
# Warning, detected jump in observation residual of size 5.57732 for observable type 1
# Warning, detected jump in observation residual of size 5.57732 for observable type 1
# Warning, detected jump in observation residual of size 5.57728 for observable type 1
# Warning, detected jump in observation residual of size 5.57728 for observable type 1
# Warning, detected jump in observation residual of size 5.57725 for observable type 1
# Warning, detected jump in observation residual of size 5.57725 for observable type 1
# Warning, detected jump in observation residual of size 3.30513 for observable type 1
# Warning, detected jump in observation residual of size 3.30121 for observable type 1
# Warning, detected jump in observation residual of size 3.44189 for observable type 1
# Warning, detected jump in observation residual of size 3.442 for observable type 1
# Warning, detected jump in observation residual of size 3.44202 for observable type 1
# Warning, detected jump in observation residual of size 3.44208 for observable type 1
# Warning, detected jump in observation residual of size 3.44209 for observable type 1
# Warning, detected jump in observation residual of size 3.44214 for observable type 1
# Warning, detected jump in observation residual of size 3.44216 for observable type 1
# Warning, detected jump in observation residual of size 3.44221 for observable type 1
# Warning, detected jump in observation residual of size 3.44223 for observable type 1
# Warning, detected jump in observation residual of size 3.69007 for observable type 1
# Warning, detected jump in observation residual of size 3.86147 for observable type 1
# Warning, detected jump in observation residual of size 3.86151 for observable type 1
# Warning, detected jump in observation residual of size 3.86152 for observable type 1
# Warning, detected jump in observation residual of size 3.86159 for observable type 1
# Warning, detected jump in observation residual of size 3.8616 for observable type 1
# Warning, detected jump in observation residual of size 5.23504 for observable type 1
# Warning, detected jump in observation residual of size 5.02061 for observable type 1
# Warning, detected jump in observation residual of size 5.02061 for observable type 1
# Warning, detected jump in observation residual of size 5.02062 for observable type 1
# Warning, detected jump in observation residual of size 5.18201 for observable type 1
# Warning, detected jump in observation residual of size 5.71663 for observable type 1
# Warning, detected jump in observation residual of size 5.71668 for observable type 1
# Warning, detected jump in observation residual of size 5.71669 for observable type 1
# Warning, detected jump in observation residual of size 5.94019 for observable type 1
# Warning, detected jump in observation residual of size 5.9889 for observable type 1
# Warning, detected jump in observation residual of size 3.16076 for observable type 1
# Warning, detected jump in observation residual of size 5.90814 for observable type 1
# Warning, detected jump in observation residual of size 3.3434 for observable type 1
# Warning, detected jump in observation residual of size 5.89315 for observable type 1
# Warning, detected jump in observation residual of size 3.88054 for observable type 1
# Warning, detected jump in observation residual of size 5.81903 for observable type 1
# Warning, detected jump in observation residual of size 5.98491 for observable type 1
# Warning, detected jump in observation residual of size 5.98498 for observable type 1
# Warning, detected jump in observation residual of size 5.98498 for observable type 1
# Warning, detected jump in observation residual of size 5.38936 for observable type 1
# Warning, detected jump in observation residual of size 5.73098 for observable type 1
# Warning, detected jump in observation residual of size 5.73101 for observable type 1
# Warning, detected jump in observation residual of size 5.73102 for observable type 1
# Warning, detected jump in observation residual of size 5.73104 for observable type 1
# Warning, detected jump in observation residual of size 5.73105 for observable type 1
# Warning, detected jump in observation residual of size 3.39658 for observable type 1
# Warning, detected jump in observation residual of size 4.51291 for observable type 1
# Warning, detected jump in observation residual of size 4.46194 for observable type 1
# Warning, detected jump in observation residual of size 4.46232 for observable type 1
# Warning, detected jump in observation residual of size 4.46254 for observable type 1
# Warning, detected jump in observation residual of size 4.46302 for observable type 1
# Warning, detected jump in observation residual of size 4.46329 for observable type 1
# Warning, detected jump in observation residual of size 4.73772 for observable type 1
# Warning, detected jump in observation residual of size 4.86552 for observable type 1
# Warning, detected jump in observation residual of size 4.866 for observable type 1
# Warning, detected jump in observation residual of size 4.86618 for observable type 1
# Warning, detected jump in observation residual of size 4.86667 for observable type 1
# Warning, detected jump in observation residual of size 4.86685 for observable type 1
# Warning, detected jump in observation residual of size 4.86734 for observable type 1
# Warning, detected jump in observation residual of size 4.86752 for observable type 1
# Warning, detected jump in observation residual of size 5.97672 for observable type 1
# Warning, detected jump in observation residual of size 5.3283 for observable type 1
# Warning, detected jump in observation residual of size 3.96966 for observable type 1
# Warning, detected jump in observation residual of size 3.96968 for observable type 1
# Warning, detected jump in observation residual of size 3.96967 for observable type 1
# Warning, detected jump in observation residual of size 4.02037 for observable type 1
# Warning, detected jump in observation residual of size 3.99098 for observable type 1
# Warning, detected jump in observation residual of size 4.04879 for observable type 1
# Warning, detected jump in observation residual of size 4.01406 for observable type 1
# Warning, detected jump in observation residual of size 4.01408 for observable type 1
# Warning, detected jump in observation residual of size 4.01408 for observable type 1
# Warning, detected jump in observation residual of size 4.08473 for observable type 1
# Warning, detected jump in observation residual of size 4.03975 for observable type 1
# Warning, detected jump in observation residual of size 4.03976 for observable type 1
# Warning, detected jump in observation residual of size 4.03975 for observable type 1
# Warning, detected jump in observation residual of size 4.04717 for observable type 1
# Warning, detected jump in observation residual of size 4.04221 for observable type 1
# Warning, detected jump in observation residual of size 4.04222 for observable type 1
# Warning, detected jump in observation residual of size 4.04221 for observable type 1
# Warning, detected jump in observation residual of size 4.04956 for observable type 1
# Warning, detected jump in observation residual of size 4.04458 for observable type 1
# Warning, detected jump in observation residual of size 4.0446 for observable type 1
# Warning, detected jump in observation residual of size 4.04459 for observable type 1
# Warning, detected jump in observation residual of size 4.14143 for observable type 1
# Warning, detected jump in observation residual of size 4.05898 for observable type 1
# Warning, detected jump in observation residual of size 4.05899 for observable type 1
# Warning, detected jump in observation residual of size 4.05897 for observable type 1
# Warning, detected jump in observation residual of size 3.71207 for observable type 1
# Warning, detected jump in observation residual of size 3.91669 for observable type 1
# Warning, detected jump in observation residual of size 3.93901 for observable type 1
# Warning, detected jump in observation residual of size 3.92897 for observable type 1
# Warning, detected jump in observation residual of size 3.929 for observable type 1
# Warning, detected jump in observation residual of size 3.92899 for observable type 1
# Warning, detected jump in observation residual of size 3.71743 for observable type 1
# Warning, detected jump in observation residual of size 4.45549 for observable type 1
# Warning, detected jump in observation residual of size 4.45534 for observable type 1
# Warning, detected jump in observation residual of size 4.45533 for observable type 1
# Warning, detected jump in observation residual of size 4.45514 for observable type 1
# Warning, detected jump in observation residual of size 4.45512 for observable type 1
# Warning, detected jump in observation residual of size 4.21804 for observable type 1
# Warning, detected jump in observation residual of size 4.15566 for observable type 1
# Warning, detected jump in observation residual of size 4.15558 for observable type 1
# Warning, detected jump in observation residual of size 4.15554 for observable type 1
# Warning, detected jump in observation residual of size 4.15542 for observable type 1
# Warning, detected jump in observation residual of size 4.15536 for observable type 1
# Warning, detected jump in observation residual of size 4.15529 for observable type 1
# Warning, detected jump in observation residual of size 4.15526 for observable type 1
# Warning, detected jump in observation residual of size 4.15524 for observable type 1
# Warning, detected jump in observation residual of size 4.15524 for observable type 1
# Warning, detected jump in observation residual of size 3.71253 for observable type 1
# Warning, detected jump in observation residual of size 3.92584 for observable type 1
# Warning, detected jump in observation residual of size 3.92582 for observable type 1
# Warning, detected jump in observation residual of size 3.92581 for observable type 1
# Warning, detected jump in observation residual of size 3.92579 for observable type 1
# Warning, detected jump in observation residual of size 3.92578 for observable type 1
# Warning, detected jump in observation residual of size 3.01231 for observable type 1
# Warning, detected jump in observation residual of size 3.35372 for observable type 1
# Warning, detected jump in observation residual of size 3.35376 for observable type 1
# Warning, detected jump in observation residual of size 3.35378 for observable type 1
# Warning, detected jump in observation residual of size 4.06029 for observable type 1
# Warning, detected jump in observation residual of size 4.08935 for observable type 1
# Warning, detected jump in observation residual of size 4.08937 for observable type 1
# Warning, detected jump in observation residual of size 4.08936 for observable type 1
# Warning, detected jump in observation residual of size 4.08939 for observable type 1
# Warning, detected jump in observation residual of size 4.08939 for observable type 1
# Warning, detected jump in observation residual of size 3.26679 for observable type 1
# Warning, detected jump in observation residual of size 3.3181 for observable type 1
# Warning, detected jump in observation residual of size 3.33781 for observable type 1
# Warning, detected jump in observation residual of size 3.33572 for observable type 1
# Warning, detected jump in observation residual of size 3.35517 for observable type 1
# Warning, detected jump in observation residual of size 3.35296 for observable type 1
# Warning, detected jump in observation residual of size 3.35302 for observable type 1
# Warning, detected jump in observation residual of size 3.35301 for observable type 1
# Warning, detected jump in observation residual of size 4.31763 for observable type 1
# Warning, detected jump in observation residual of size 4.30207 for observable type 1
# Warning, detected jump in observation residual of size 4.30205 for observable type 1
# Warning, detected jump in observation residual of size 4.30205 for observable type 1
# Warning, detected jump in observation residual of size 4.30203 for observable type 1
# Warning, detected jump in observation residual of size 4.30203 for observable type 1
# Warning, detected jump in observation residual of size 4.30202 for observable type 1
# Warning, detected jump in observation residual of size 4.30201 for observable type 1
# Warning, detected jump in observation residual of size 4.302 for observable type 1
# Warning, detected jump in observation residual of size 4.30199 for observable type 1
# Warning, detected jump in observation residual of size 4.14447 for observable type 1
# Warning, detected jump in observation residual of size 3.99625 for observable type 1
# Warning, detected jump in observation residual of size 3.99627 for observable type 1
# Warning, detected jump in observation residual of size 3.99626 for observable type 1
# Warning, detected jump in observation residual of size 3.99628 for observable type 1
# Warning, detected jump in observation residual of size 3.99627 for observable type 1
# Warning, detected jump in observation residual of size 3.99629 for observable type 1
# Warning, detected jump in observation residual of size 3.99628 for observable type 1
# Warning, detected jump in observation residual of size 3.99629 for observable type 1
# Warning, detected jump in observation residual of size 3.99629 for observable type 1
# Warning, detected jump in observation residual of size 3.99631 for observable type 1
# Warning, detected jump in observation residual of size 3.9963 for observable type 1
# Warning, detected jump in observation residual of size 3.61725 for observable type 1
# Warning, detected jump in observation residual of size 3.70617 for observable type 1
# Warning, detected jump in observation residual of size 3.70639 for observable type 1
# Warning, detected jump in observation residual of size 3.70629 for observable type 1
# Warning, detected jump in observation residual of size 3.70651 for observable type 1
# Warning, detected jump in observation residual of size 3.70641 for observable type 1
# Warning, detected jump in observation residual of size 3.71665 for observable type 1
# Warning, detected jump in observation residual of size 3.71213 for observable type 1
# Warning, detected jump in observation residual of size 3.71235 for observable type 1
# Warning, detected jump in observation residual of size 3.71225 for observable type 1
# Warning, detected jump in observation residual of size 3.71246 for observable type 1
# Warning, detected jump in observation residual of size 3.71236 for observable type 1
# Warning, detected jump in observation residual of size 3.72259 for observable type 1
# Warning, detected jump in observation residual of size 3.71804 for observable type 1
# Warning, detected jump in observation residual of size 3.71825 for observable type 1
# Warning, detected jump in observation residual of size 3.71815 for observable type 1
# Warning, detected jump in observation residual of size 3.71837 for observable type 1
# Warning, detected jump in observation residual of size 3.71827 for observable type 1
# Warning, detected jump in observation residual of size 3.39152 for observable type 1
# Warning, detected jump in observation residual of size 3.90919 for observable type 1
# Warning, detected jump in observation residual of size 3.90931 for observable type 1
# Warning, detected jump in observation residual of size 3.90925 for observable type 1
# Warning, detected jump in observation residual of size 3.90936 for observable type 1
# Warning, detected jump in observation residual of size 3.9093 for observable type 1
# Warning, detected jump in observation residual of size 3.90942 for observable type 1
# Warning, detected jump in observation residual of size 3.90935 for observable type 1
# Warning, detected jump in observation residual of size 3.85103 for observable type 1
# Warning, detected jump in observation residual of size 4.03258 for observable type 1
# Warning, detected jump in observation residual of size 4.03251 for observable type 1
# Warning, detected jump in observation residual of size 4.03247 for observable type 1
# Warning, detected jump in observation residual of size 4.03241 for observable type 1
# Warning, detected jump in observation residual of size 4.03237 for observable type 1
# Warning, detected jump in observation residual of size 4.03232 for observable type 1
# Warning, detected jump in observation residual of size 4.03226 for observable type 1
# Warning, detected jump in observation residual of size 3.21238 for observable type 1
# Warning, detected jump in observation residual of size 3.84976 for observable type 1
# Warning, detected jump in observation residual of size 3.84981 for observable type 1
# Warning, detected jump in observation residual of size 3.84978 for observable type 1
# Warning, detected jump in observation residual of size 3.84983 for observable type 1
# Warning, detected jump in observation residual of size 3.8498 for observable type 1
# Warning, detected jump in observation residual of size 3.84985 for observable type 1
# Warning, detected jump in observation residual of size 3.84982 for observable type 1
# Warning, detected jump in observation residual of size 3.74002 for observable type 1
# Warning, detected jump in observation residual of size 3.86243 for observable type 1
# Warning, detected jump in observation residual of size 3.86254 for observable type 1
# Warning, detected jump in observation residual of size 3.86248 for observable type 1
# Warning, detected jump in observation residual of size 3.86259 for observable type 1
# Warning, detected jump in observation residual of size 3.86253 for observable type 1
# Warning, detected jump in observation residual of size 3.86265 for observable type 1
# Warning, detected jump in observation residual of size 3.86259 for observable type 1
# Warning, detected jump in observation residual of size 3.8627 for observable type 1
# Warning, detected jump in observation residual of size 3.86264 for observable type 1
# Warning, detected jump in observation residual of size 3.19814 for observable type 1
# Warning, detected jump in observation residual of size 3.59144 for observable type 1
# Warning, detected jump in observation residual of size 3.59148 for observable type 1
# Warning, detected jump in observation residual of size 3.59146 for observable type 1
# Warning, detected jump in observation residual of size 3.5915 for observable type 1
# Warning, detected jump in observation residual of size 3.59148 for observable type 1
# Warning, detected jump in observation residual of size 3.59151 for observable type 1
# Warning, detected jump in observation residual of size 3.5915 for observable type 1
# Warning, detected jump in observation residual of size 3.59153 for observable type 1
# Warning, detected jump in observation residual of size 3.59151 for observable type 1
# Warning, detected jump in observation residual of size 3.59155 for observable type 1
# Warning, detected jump in observation residual of size 3.59153 for observable type 1
# Warning, detected jump in observation residual of size 3.59157 for observable type 1
# Warning, detected jump in observation residual of size 3.59155 for observable type 1
# Warning, detected jump in observation residual of size 3.59158 for observable type 1
# Warning, detected jump in observation residual of size 3.59157 for observable type 1
# Warning, detected jump in observation residual of size 3.74117 for observable type 1
# Warning, detected jump in observation residual of size 3.6003 for observable type 1
# Warning, detected jump in observation residual of size 3.60055 for observable type 1
# Warning, detected jump in observation residual of size 3.60045 for observable type 1
# Warning, detected jump in observation residual of size 3.60066 for observable type 1
# Warning, detected jump in observation residual of size 3.60057 for observable type 1
# Warning, detected jump in observation residual of size 4.15396 for observable type 1
# Warning, detected jump in observation residual of size 4.18702 for observable type 1
# Warning, detected jump in observation residual of size 4.18661 for observable type 1
# Warning, detected jump in observation residual of size 4.1865 for observable type 1
# Warning, detected jump in observation residual of size 4.18643 for observable type 1
# Warning, detected jump in observation residual of size 4.18641 for observable type 1
# Warning, detected jump in observation residual of size 3.13017 for observable type 1
# Warning, detected jump in observation residual of size 3.77754 for observable type 1
# Warning, detected jump in observation residual of size 3.77789 for observable type 1
# Warning, detected jump in observation residual of size 3.77771 for observable type 1
# Warning, detected jump in observation residual of size 3.83315 for observable type 1
# Warning, detected jump in observation residual of size 3.81764 for observable type 1
# Warning, detected jump in observation residual of size 3.81771 for observable type 1
# Warning, detected jump in observation residual of size 3.81767 for observable type 1
# Warning, detected jump in observation residual of size 3.81781 for observable type 1
# Warning, detected jump in observation residual of size 3.81773 for observable type 1
# Warning, detected jump in observation residual of size 3.60058 for observable type 1
# Warning, detected jump in observation residual of size 3.60604 for observable type 1
# Warning, detected jump in observation residual of size 3.60609 for observable type 1
# Warning, detected jump in observation residual of size 3.60609 for observable type 1
# Warning, detected jump in observation residual of size 3.10263 for observable type 1
# Warning, detected jump in observation residual of size 3.36755 for observable type 1
# Warning, detected jump in observation residual of size 3.36758 for observable type 1
# Warning, detected jump in observation residual of size 3.36759 for observable type 1
# Warning, detected jump in observation residual of size 3.3676 for observable type 1
# Warning, detected jump in observation residual of size 3.36762 for observable type 1
# Warning, detected jump in observation residual of size 3.391 for observable type 1
# Warning, detected jump in observation residual of size 4.16185 for observable type 1
# Warning, detected jump in observation residual of size 4.16179 for observable type 1
# Warning, detected jump in observation residual of size 4.16176 for observable type 1
# Warning, detected jump in observation residual of size 4.16167 for observable type 1
# Warning, detected jump in observation residual of size 4.16162 for observable type 1
# Warning, detected jump in observation residual of size 4.14503 for observable type 1
# Warning, detected jump in observation residual of size 4.13622 for observable type 1
# Warning, detected jump in observation residual of size 4.13615 for observable type 1
# Warning, detected jump in observation residual of size 4.13611 for observable type 1
# Warning, detected jump in observation residual of size 4.13601 for observable type 1
# Warning, detected jump in observation residual of size 4.13595 for observable type 1
# Warning, detected jump in observation residual of size 3.74161 for observable type 1
# Warning, detected jump in observation residual of size 3.56747 for observable type 1
# Warning, detected jump in observation residual of size 3.56753 for observable type 1
# Warning, detected jump in observation residual of size 3.56751 for observable type 1
# Warning, detected jump in observation residual of size 3.56757 for observable type 1
# Warning, detected jump in observation residual of size 3.56755 for observable type 1
# Warning, detected jump in observation residual of size 3.56762 for observable type 1
# Warning, detected jump in observation residual of size 3.5676 for observable type 1
# Warning, detected jump in observation residual of size 3.85107 for observable type 1
# Warning, detected jump in observation residual of size 3.76258 for observable type 1
# Warning, detected jump in observation residual of size 3.76264 for observable type 1
# Warning, detected jump in observation residual of size 3.76262 for observable type 1
# Warning, detected jump in observation residual of size 3.76269 for observable type 1
# Warning, detected jump in observation residual of size 3.76266 for observable type 1
# Warning, detected jump in observation residual of size 3.76272 for observable type 1
# Warning, detected jump in observation residual of size 3.7627 for observable type 1
# Warning, detected jump in observation residual of size 3.28281 for observable type 1
# Warning, detected jump in observation residual of size 3.37422 for observable type 1
# Warning, detected jump in observation residual of size 3.37425 for observable type 1
# Warning, detected jump in observation residual of size 3.37425 for observable type 1
# Warning, detected jump in observation residual of size 3.41051 for observable type 1
# Warning, detected jump in observation residual of size 3.40478 for observable type 1
# Warning, detected jump in observation residual of size 3.40482 for observable type 1
# Warning, detected jump in observation residual of size 3.40482 for observable type 1
# Warning, detected jump in observation residual of size 4.05828 for observable type 1
# Warning, detected jump in observation residual of size 3.89902 for observable type 1
# Warning, detected jump in observation residual of size 3.89885 for observable type 1
# Warning, detected jump in observation residual of size 3.89874 for observable type 1
# Warning, detected jump in observation residual of size 4.04278 for observable type 1
# Warning, detected jump in observation residual of size 3.85373 for observable type 1
# Warning, detected jump in observation residual of size 3.85384 for observable type 1
# Warning, detected jump in observation residual of size 3.85378 for observable type 1
# Warning, detected jump in observation residual of size 3.85387 for observable type 1
# Warning, detected jump in observation residual of size 3.85381 for observable type 1
# Warning, detected jump in observation residual of size 3.81092 for observable type 1
# Warning, detected jump in observation residual of size 3.95572 for observable type 1
# Warning, detected jump in observation residual of size 3.95565 for observable type 1
# Warning, detected jump in observation residual of size 3.95563 for observable type 1
# Warning, detected jump in observation residual of size 3.95523 for observable type 1
# Warning, detected jump in observation residual of size 3.95508 for observable type 1
# Warning, detected jump in observation residual of size 3.95506 for observable type 1
# Warning, detected jump in observation residual of size 3.95506 for observable type 1
# Warning, detected jump in observation residual of size 3.95504 for observable type 1
# Warning, detected jump in observation residual of size 3.95503 for observable type 1
# Warning, detected jump in observation residual of size 3.9301 for observable type 1
# Warning, detected jump in observation residual of size 3.77085 for observable type 1
# Warning, detected jump in observation residual of size 3.77083 for observable type 1
# Warning, detected jump in observation residual of size 3.77083 for observable type 1
# Warning, detected jump in observation residual of size 3.77079 for observable type 1
# Warning, detected jump in observation residual of size 3.77079 for observable type 1
# Warning, detected jump in observation residual of size 3.77077 for observable type 1
# Warning, detected jump in observation residual of size 3.77076 for observable type 1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Perform the estimation
# ----> 2 pod_output = estimator.perform_estimation(pod_input)
#
# RuntimeError: Error computing observation of type AngularPosition with link ends transmitter: (66146); receiver: (Earth, 084) at epoch 188883653.143805.
# Original error: Error in light-time solution, computing light time with reference epoch 188883653.143805 (DateTime: 2005-12-26 15:40:53.143805265426636) at receiver.
# Original error: Error in ephemeris, requesting state at epoch -273975486.229371.
# Original error: Error when setting global state of 66146 from ephemeris.
# Original error: Error in ephemeris, requesting state at epoch -273975486.229371.
# Original error: Error in tabulated ephemeris.
# Original error: Error in interpolator, requesting data point outside of boundaries, requested data at -273975486.229371 but limit values are 18564629.142585 and 409812629.142585

# %%
# retrieve the estimated initial state.
results_final = pod_output.parameter_history[:, -1]

vector_error_initial = (np.array(initial_guess) - initial_states)[0:3]
error_magnitude_initial = np.sqrt(np.square(vector_error_initial).sum()) / 1000

vector_error_final = (np.array(results_final) - initial_states)[0:3]
error_magnitude_final = np.sqrt(np.square(vector_error_final).sum()) / 1000

print(
    f"{target_name} initial guess radial error to spice: {round(error_magnitude_initial, 2)} km"
)
print(
    f"{target_name} final radial error to spice: {round(error_magnitude_final, 2)} km"
)

# %%
residual_history = pod_output.residual_history

# Number of columns and rows for our plot
number_of_columns = 2

number_of_rows = (
    int(number_of_pod_iterations / number_of_columns)
    if number_of_pod_iterations % number_of_columns == 0
    else int((number_of_pod_iterations + 1) / number_of_columns)
)

fig, axs = plt.subplots(
    number_of_rows,
    number_of_columns,
    figsize=(9, 3.5 * number_of_rows),
    sharex=True,
    sharey=False,
)

# We cheat a little to get an approximate year out of our times (which are in seconds since J2000)
residual_times = (
    np.array(observation_collection.concatenated_times) / (86400 * 365.25) + 2000
)


# plot the residuals, split between RA and DEC types
for idx, ax in enumerate(fig.get_axes()):
    ax.grid()
    # we take every second
    ax.scatter(
        residual_times[::2],
        residual_history[
            ::2,
            idx,
        ],
        marker="+",
        s=60,
        label="Right Ascension",
    )
    ax.scatter(
        residual_times[1::2],
        residual_history[
            1::2,
            idx,
        ],
        marker="+",
        s=60,
        label="Declination",
    )
    ax.set_ylabel("Observation Residual [rad]")
    ax.set_title("Iteration " + str(idx + 1))

plt.tight_layout()

# add the year label for the x-axis
for col in range(number_of_columns):
    axs[int(number_of_rows - 1), col].set_xlabel("Year")

axs[0, 0].legend()

plt.show()

# %%
# Correlation can be retrieved using the CovarianceAnalysisInput class:
covariance_input = estimation_analysis.CovarianceAnalysisInput(observation_collection)
covariance_output = estimator.compute_covariance(covariance_input)

correlations = covariance_output.correlations
estimated_param_names = ["x", "y", "z", "vx", "vy", "vz"]


fig, ax = plt.subplots(1, 1, figsize=(9, 7))

im = ax.imshow(correlations, cmap=cm.RdYlBu_r, vmin=-1, vmax=1)

ax.set_xticks(np.arange(len(estimated_param_names)), labels=estimated_param_names)
ax.set_yticks(np.arange(len(estimated_param_names)), labels=estimated_param_names)

# add numbers to each of the boxes
for i in range(len(estimated_param_names)):
    for j in range(len(estimated_param_names)):
        text = ax.text(
            j, i, round(correlations[i, j], 2), ha="center", va="center", color="w"
        )

cb = plt.colorbar(im)

ax.set_xlabel("Estimated Parameter")
ax.set_ylabel("Estimated Parameter")

fig.suptitle(f"Correlations for estimated parameters for {target_name}")

fig.set_tight_layout(True)

# %%
# lets get ranges for all gaps larger than 6 months:
gap_in_months = 6

gaps = np.abs(np.diff(sorted(residual_times)))
num_gaps = (
    gaps > (gap_in_months / 12)
).sum()  # counts the number of gaps larger than 0.5 years
indices_of_largest_gaps = np.argsort(gaps)[-num_gaps:]

# (start, end) for each of the gaps
gap_ranges = [
    (sorted(residual_times)[idx - 1], sorted(residual_times)[idx + 1])
    for idx in indices_of_largest_gaps
]

print(f"Largest gap = {round(max(gaps), 3)} years")
print(gap_ranges)

# %%
# Now lets plot the orbit error
fig, ax = plt.subplots(1, 1, figsize=(9, 5))

# show areas where there are no observations:
for i, gap in enumerate(gap_ranges):
    ax.axvspan(
        xmin=gap[0],
        xmax=gap[1],
        color="red",
        alpha=0.1,
        label="Large gap in observations" if i == 0 else None,
    )

spice_states = []
estimation_states = []

# retrieve the states for a list of times.
times = np.linspace(epoch_start_nobuffer, epoch_end_nobuffer, 1000)
times_plot = times / (86400 * 365.25) + 2000  # approximate
for time in times:
    # from spice
    state_spice = spice.get_body_cartesian_state_at_epoch(
        target_spkid, central_bodies[0], global_frame_orientation, "NONE", time
    )
    spice_states.append(state_spice)

    # from estimation
    state_est = bodies.get(str(target_mpc_code)).ephemeris.cartesian_state(time)
    estimation_states.append(state_est)

# Error in kilometers
error = (np.array(spice_states) - np.array(estimation_states)) / 1000

# plot
ax.plot(times_plot, error[:, 0], label="x")
ax.plot(times_plot, error[:, 1], label="y")
ax.plot(times_plot, error[:, 2], label="z")

ax.grid()
ax.legend(ncol=1)

plt.tight_layout()

ax.set_ylabel("Cartesian Error [km]")
ax.set_xlabel("Year")

fig.suptitle(f"Error vs SPICE over time for {target_name}")
fig.set_tight_layout(True)

plt.show()

# %%
# 10 observatories with most observations
num_observatories = 10

final_residuals = np.array(residual_history[:, -1])
# if you would like to check the iteration 1 residuals, use:
# final_residuals = np.array(residual_history[:, 0])

# %%
# This piece of code collects the 10 largest observatories
observatory_names = (
    batch.observatories_table(exclude_space_telescopes=True)
    .sort_values("count", ascending=False)
    .iloc[0:num_observatories]
    .set_index("Code")
)
top_observatories = observatory_names.index.tolist()

# This piece of code creates a `concatenated_receiving_observatories` map
# to identify the observatories by their MPC code instead of an internally used id
residuals_observatories = observation_collection.concatenated_link_definition_ids
unique_observatories = set(residuals_observatories)

observatory_link_to_mpccode = {
    idx: observation_collection.link_definition_ids[idx][
        observable_models_setup.links.receiver
    ].reference_point
    for idx in unique_observatories
}

# the resulting map (MPC code for each item in the residuals_history):
concatenated_receiving_observatories = np.array(
    [observatory_link_to_mpccode[idx] for idx in residuals_observatories]
)

# mask for the observatories not in top 10:
mask_not_top = [
    (False if observatory in top_observatories else True)
    for observatory in concatenated_receiving_observatories
]

# get the number of observations by the other observatories
# (divide by two because the observations are concatenated RA,DEC in this list)
n_obs_not_top = int(sum(mask_not_top) / 2)

# %%
fig, axs = plt.subplots(2, 1, figsize=(13, 9))

# Plot remaining observatories first
# RA
axs[0].scatter(
    residual_times[mask_not_top][::2],
    final_residuals[mask_not_top][::2],
    marker=".",
    s=30,
    label=f"{len(unique_observatories) - num_observatories} Other Observatories | {n_obs_not_top} obs",
    color="lightgrey",
)
# DEC
axs[1].scatter(
    residual_times[mask_not_top][1::2],
    final_residuals[mask_not_top][1::2],
    marker=".",
    s=30,
    label=f"{len(unique_observatories) - num_observatories} Other Observatories | {n_obs_not_top} obs",
    color="lightgrey",
)

# plots the highlighted top 10 observatories
for observatory in top_observatories:
    name = f"{observatory} | {observatory_names.loc[observatory].Name} | {int(observatory_names.loc[observatory]['count'])} obs"
    axs[0].scatter(
        residual_times[concatenated_receiving_observatories == observatory][::2],
        final_residuals[concatenated_receiving_observatories == observatory][::2],
        marker=".",
        s=30,
        label=name,
        zorder=100,
    )
    axs[1].scatter(
        residual_times[concatenated_receiving_observatories == observatory][1::2],
        final_residuals[concatenated_receiving_observatories == observatory][1::2],
        marker=".",
        s=30,
        label=name,
        zorder=100,
    )


axs[1].legend(ncols=3, loc="upper center", bbox_to_anchor=(0.47, -0.15))

for ax in fig.get_axes():
    ax.grid()
    ax.set_ylabel("Observation Residual [rad]")
    ax.set_xlabel("Year")
    # this step hides a few outliers (~3 observations)
    ax.set_ylim(-1.5e-5, 1.5e-5)

axs[0].set_title("Right Ascension")
axs[1].set_title("Declination")

fig.suptitle(f"Final Iteration residuals for {target_name}")
fig.set_tight_layout(True)

plt.show()

# %%
num_observatories = 6

data_per_observatory_list_RA = []
data_per_observatory_list_DEC = []
names = []

fig, ax = plt.subplots(1, 1, figsize=(10, 1.2 * num_observatories))

# we retrieve the observatory names again
observatory_names_box = (
    batch.observatories_table(exclude_space_telescopes=True)
    .set_index("Code")
    .sort_values("count", ascending=False)
    .iloc[0:num_observatories]
)

top_observatories_box = observatory_names_box.index.tolist()

# retrieve the data for RA and DEC separately
for observatory in top_observatories_box[::-1]:
    name = f"{observatory} | {observatory_names_box.loc[observatory].Name} | {int(observatory_names_box.loc[observatory]['count'])} obs"
    names.append(name)
    data_per_observatory_list_RA.append(
        final_residuals[concatenated_receiving_observatories == observatory][::2]
    )

    data_per_observatory_list_DEC.append(
        final_residuals[concatenated_receiving_observatories == observatory][1::2]
    )

# positioning the boxes
pos = (np.arange(0, len(top_observatories_box)) + 1) * 10
widths = 2.8
offset = 1.6

# box colors
RA_color = "tab:blue"
DEC_color = "tab:orange"

# boxes for RA and DEC
RAplots = ax.boxplot(
    x=data_per_observatory_list_RA,
    vert=False,
    positions=pos + offset,
    widths=widths,
    patch_artist=False,
    capprops=dict(color=RA_color),
    whiskerprops=dict(color=RA_color),
    flierprops=dict(color=RA_color, markeredgecolor=RA_color),
    medianprops=dict(color=RA_color),
)
DECplots = ax.boxplot(
    x=data_per_observatory_list_DEC,
    vert=False,
    positions=pos - offset,
    widths=widths,
    patch_artist=False,
    capprops=dict(color=DEC_color),
    whiskerprops=dict(color=DEC_color),
    flierprops=dict(color=DEC_color, markeredgecolor=DEC_color),
    medianprops=dict(color=DEC_color),
)
# custom ticks
ax.set_yticks(ticks=pos, labels=names)

# custom legend
place_holder_lines = [
    Line2D([0], [0], color=RA_color, lw=4),
    Line2D([0], [0], color=DEC_color, lw=4),
]
ax.legend(place_holder_lines, ["Right Ascension", "Declination"])

ax.grid()
ax.set_xlabel("Observation Residual [rad]")

fig.suptitle(
    f"Residual boxplots of the {num_observatories} observatories with the most observations for {target_name}"
)

# reducing whitespace
ax.set_ylim(10 - 4, int(len(top_observatories_box) * 10) + 4)

fig.set_tight_layout(True)
plt.show()

# %%
num_observatories = 6
nbins = 20
number_of_columns = 2
transparency = 0.6

# %%
number_of_rows = (
    int(num_observatories / number_of_columns)
    if num_observatories % number_of_columns == 0
    else int((num_observatories + 1) / number_of_columns)
)

# we retrieve the observatory names again
observatory_names_hist = (
    batch.observatories_table(exclude_space_telescopes=True)
    .set_index("Code")
    .sort_values("count", ascending=False)
    .iloc[0:num_observatories]
)

top_observatories_hist = observatory_names_hist.index.tolist()


fig, axs = plt.subplots(
    number_of_rows,
    number_of_columns,
    figsize=(4.5 * number_of_columns, 3 * number_of_rows),
)

axs = axs.flatten()

for idx, observatory in enumerate(top_observatories_hist):
    name = f"{observatory} | {observatory_names_hist.loc[observatory].Name} | {int(observatory_names_hist.loc[observatory]['count'])} obs"

    axs[idx].hist(
        final_residuals[concatenated_receiving_observatories == observatory][0::2],
        bins=nbins,
        alpha=transparency + 0.05,
        label="Right Ascension",
    )
    axs[idx].hist(
        final_residuals[concatenated_receiving_observatories == observatory][1::2],
        bins=nbins,
        alpha=transparency,
        label="Declination",
    )

    axs[idx].grid()
    axs[idx].set_title(name)
    axs[idx].set_ylabel("Number of Observations")
    axs[idx].set_xlabel("Observation Residual [rad]")

axs[0].legend()

fig.suptitle(
    f"Final residual histograms of the {num_observatories} observatories with the most observations for {target_name}"
)
fig.set_tight_layout(True)
plt.show()
